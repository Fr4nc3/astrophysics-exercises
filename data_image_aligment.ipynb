# %%
import astropy
from astropy.io import fits
import matplotlib.pyplot as plt
import numpy as np
import os

# Config
wd = r"C:\Users\friesco\workstation\fr-p\studies\ASTRO716\data_excercise"
plt.rcParams['figure.figsize'] = [10, 8]

# Function
def analyze_hdr(fp):
    try:
        with fits.open(fp) as hdu:
            hdr = hdu[0].header
            date_obs = hdr.get('DATE-OBS', 'N/A')
            mjd = hdr.get('MJD', 'N/A')
            exptime = hdr.get('EXPTIME', 'N/A')
            gain = hdr.get('GAIN', 'N/A')
            airmass = hdr.get('AIRMASS', 'N/A')

            print(f"Analyzing: {os.path.basename(fp)}")
            print(f"  DATE-OBS: {date_obs}")
            print(f"  MJD: {mjd}")
            print(f"  EXPTIME: {exptime}")
            print(f"  GAIN: {gain}")
            print(f"  AIRMASS: {airmass}")

            nova_x, nova_y = 1000, 1500
            print(f"  Nova Pos (x, y): ({nova_x}, {nova_y})")

            img_data = hdu['image'].data if 'image' in hdu else hdu[0].data
            if img_data.dtype.byteorder == '>':
                img_data = img_data.byteswap().view(img_data.dtype.newbyteorder('<'))

            if nova_x is not None and nova_y is not None:
                rad = 20
                y_min, y_max = max(0, nova_y - rad), min(img_data.shape[0], nova_y + rad)
                x_min, x_max = max(0, nova_x - rad), min(img_data.shape[1], nova_x + rad)
                nova_reg = img_data[y_min:y_max, x_min:x_max]

                thresh = np.mean(nova_reg) + 2 * np.std(nova_reg)
                psf_size = np.sum(nova_reg > thresh)
                print(f"  PSF Size: {psf_size}")

                plt.imshow(nova_reg, origin='lower', cmap='viridis')
                plt.title("Nova Region")
                plt.colorbar()
                plt.show()

            print("-" * 30)
    except FileNotFoundError:
        print(f"File not found: {fp}")
    except Exception as e:
        print(f"Error: {e}")

# Main
phot_files = [f for f in os.listdir(wd) if f.startswith('phot_') and f.endswith('.fits')]
phot_files.sort()

for f in phot_files:
    path = os.path.join(wd, f)
    analyze_hdr(path)
# Out:
# Analyzing: phot_00.fits
#   DATE-OBS: 2016-07-16T01:54:04.626
#   MJD: 57585.07922
#   EXPTIME: 120.0
#   GAIN: 1.62
#   AIRMASS: 1.725891
#   Nova Pos (x, y): (1000, 1500)
#   PSF Size: 43
# ------------------------------
# Analyzing: phot_01.fits
#   DATE-OBS: 2016-07-17T01:57:55.414
#   MJD: 57586.081891
#   EXPTIME: 120.0
#   GAIN: 1.62
#   AIRMASS: 1.666524
#   Nova Pos (x, y): (1000, 1500)
#   PSF Size: 42
# ------------------------------
# Analyzing: phot_02.fits
#   DATE-OBS: 2016-07-18T01:43:20.318
#   MJD: 57587.071763
#   EXPTIME: 120.0
#   GAIN: 1.62
#   AIRMASS: 1.749186
#   Nova Pos (x, y): (1000, 1500)
#   PSF Size: 37
# ------------------------------
# Analyzing: phot_03.fits
#   DATE-OBS: 2016-07-19T01:36:39.439
#   MJD: 57588.067123
#   EXPTIME: 120.0
#   GAIN: 1.62
#   AIRMASS: 1.772115
#   Nova Pos (x, y): (1000, 1500)
#   PSF Size: 45
# ------------------------------
# Analyzing: phot_04.fits
#   DATE-OBS: 2016-07-22T02:34:57.627
#   MJD: 57591.107611
# ...
