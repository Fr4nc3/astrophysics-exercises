# %% [markdown]
# # Data Exercise TSV file

# %%
import pandas as pd
import matplotlib.pyplot as plt

file_path = r"C:\Users\friesco\workstation\fr-p\studies\ASTRO716\data_excercise\psdr1_new.tsv"

try:
    df = pd.read_csv(file_path, delimiter='\t', comment='#', header=None)
    first_row = df.iloc[0]
    if '\t' in first_row.str.cat(sep='\t'):
        df = pd.read_csv(file_path, delimiter='\t', comment='#', header=0)
    else:
        cols = ['ID', '_r', '_RAJ2000', '_DEJ2000', 'RAJ2000', 'DEJ2000', 'objID', 'f_objID', 'Qual', 'Ns', 'Nd', 'gmag', 'e_gmag', 'gFlags', 'rmag', 'e_rmag', 'rFlags', 'imag', 'e_imag', 'iFlags', 'zmag', 'e_zmag', 'zFlags']
        df.columns = cols

    # Remove separator rows (rows with hyphens)
    df = df[df['ID'] != '--']

    # Convert relevant columns to numeric types
    for col in ['RAJ2000', 'DEJ2000', 'gmag', 'e_gmag', 'rmag', 'e_rmag', 'imag', 'e_imag', 'zmag', 'e_zmag']:
        if col in df.columns:
            df[col] = pd.to_numeric(df[col], errors='coerce')

except FileNotFoundError:
    print(f"Error: '{file_path}' not found.")
    exit()
except pd.errors.ParserError:
    print("Error: Parsing failed.")
    exit()
except Exception as e:
    print(f"Error: {e}")
    exit()

print("Data Summary:")
print(df.info())
print("\nFirst 5 rows:\n", df.head())
print("\nDescriptive Statistics:\n", df.describe())

if 'objID' in df.columns:
    num_objs = df['objID'].nunique()
    print(f"\nNumber of unique objects: {num_objs}")

# Assuming 'Qual' column contains quality flags similar to objInfoFlag
if 'Qual' in df.columns:
    print("\nObject Quality Distribution:")
    print(df['Qual'].value_counts())

filters = ['g', 'r', 'i', 'z']
for f in filters:
    if f'{f}mag' in df.columns:
        plt.figure()
        plt.hist(df[f'{f}mag'].dropna(), bins=50)
        plt.title(f'{f}-band Magnitudes')
        plt.xlabel(f'{f}mag')
        plt.ylabel('Frequency')
        plt.show()

if 'rmag' in df.columns and 'imag' in df.columns:
    plt.figure()
    plt.scatter(df['rmag'], df['imag'], s=5, alpha=0.5)
    plt.title('r vs. i Magnitudes')
    plt.xlabel('r mag')
    plt.ylabel('i mag')
    plt.show()
# Out:
# Data Summary:
# <class 'pandas.core.frame.DataFrame'>
# Index: 135 entries, 1 to 135
# Data columns (total 23 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ID        135 non-null    object
#  1   _r        135 non-null    object
#  2   _RAJ2000  135 non-null    object
#  3   _DEJ2000  135 non-null    object
#  4   RAJ2000   135 non-null    float64
#  5   DEJ2000   135 non-null    float64
#  6   objID     135 non-null    object
#  7   f_objID   135 non-null    object
#  8   Qual      135 non-null    object
#  9   Ns        135 non-null    object
#  10  Nd        135 non-null    object
#  11  gmag      135 non-null    float64
#  12  e_gmag    135 non-null    float64
#  13  gFlags    135 non-null    object
#  14  rmag      135 non-null    float64
#  15  e_rmag    135 non-null    float64
#  16  rFlags    135 non-null    object
#  17  imag      135 non-null    float64
#  18  e_imag    135 non-null    float64
#  19  iFlags    135 non-null    object
#  20  zmag      135 non-null    float64
#  21  e_zmag    135 non-null    float64
#  22  zFlags    135 non-null    object
# dtypes: float64(10), object(13)
# memory usage: 25.3+ KB
# None
#
# First 5 rows:
#    ID      _r      _RAJ2000      _DEJ2000    RAJ2000    DEJ2000  \
# 1  1  0.8087  00:44:41.919  +40:07:48.14  11.174664  40.130039
# 2  2  1.2065  00:44:34.796  +40:08:43.46  11.144985  40.145406
# 3  3  1.3281  00:44:37.296  +40:09:42.57  11.155400  40.161825
# 4  4  1.4747  00:44:48.507  +40:08:59.41  11.202114  40.149836
# 5  5  1.4959  00:44:48.883  +40:08:41.70  11.203678  40.144918
#
#                 objID    f_objID Qual Ns  ...  gFlags     rmag  e_rmag  \
# 1  156150111746426685  503635968   60  5  ...  115000  17.9116  0.0067
# 2  156170111449725128  503635968   60  5  ...  115000  16.1868  0.0044
# 3  156190111553904833  436527104   52  5  ...  115000  18.0010  0.0064
# 4  156180112021090440  503635968   60  5  ...  115000  16.6114  0.0029
# 5  156170112036494555  503635968   60  5  ...  115000  17.3121  0.0048
#
#    rFlags     imag  e_imag  iFlags     zmag  e_zmag  zFlags
# 1  115000  17.7913  0.0042  115000  17.7706  0.0061  115000
# 2  115000  15.8379  0.0030  115000  15.7116  0.0021  115000
# 3  115000  17.9360  0.0067  115000  17.9725  0.0056  115000
# 4  115000  16.3756  0.0031  115000  16.2984  0.0046  115000
# 5  115000  17.1169  0.0041  115000  17.0537  0.0062  115000
#
# [5 rows x 23 columns]
#
# Descriptive Statistics:
#            RAJ2000     DEJ2000        gmag      e_gmag        rmag      e_rmag  \
# count  135.000000  135.000000  135.000000  135.000000  135.000000  135.000000
# mean    11.171530   40.145464   17.121650    0.004942   16.550026    0.004030
# std      0.079644    0.059742    1.321061    0.002723    1.237903    0.002528
# min     11.022653   40.033502   13.986500    0.001500   13.666600    0.000700
# 25%     11.100461   40.101869   16.309500    0.003600   15.829350    0.002500
# 50%     11.181464   40.145406   17.294000    0.004600   16.719700    0.003500
# 75%     11.232796   40.190367   18.193900    0.005650   17.476800    0.004800
# max     11.320456   40.255017   18.987400    0.028400   18.596100    0.020800
#
#              imag      e_imag        zmag      e_zmag
# count  135.000000  135.000000  135.000000  135.000000
# mean    16.298771    0.003495   16.211119    0.005392
# std      1.213233    0.002078    1.206110    0.004666
# min     13.575200    0.000500   13.486000    0.000000
# 25%     15.606650    0.002400   15.554200    0.003150
# 50%     16.491700    0.003200   16.305300    0.004600
# 75%     17.232650    0.004000   17.126650    0.006100
# max     18.449600    0.017400   18.451700    0.037500
#
# Number of unique objects: 135
#
# Object Quality Distribution:
# Qual
# 60     123
# 52      10
# 172      1
# 61       1
# Name: count, dtype: int64
